# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 

pd.set_option('display.max_columns', 250)

# %%
df = pd.read_csv("euro-daily-hist_1999_2022.csv")

# %%
df.rename(columns= {'Period\\Unit:':'Time', 
                   '[Australian dollar ]': 'Australian dollar',
                   '[Bulgarian lev ]': 'Bulgarian lev',
                   '[Brazilian real ]': 'Brazilian real',
                   '[Canadian dollar ]': 'Canadian dollar',
                   '[Swiss franc ]': 'Swiss franc',
                   '[Chinese yuan renminbi ]': 'Chinese yuan renminbi',
                   '[Cypriot pound ]': 'Cypriot pound',
                   '[Czech koruna ]': 'Czech koruna',
                   '[Danish krone ]': 'Danish krone',
                   '[Estonian kroon ]': 'Estonian kroon',
                   '[UK pound sterling ]': 'UK pound sterling',
                   '[Greek drachma ]': 'Greek drachma',
                   '[Hong Kong dollar ]': 'Hong Kong dollar',
                   '[Croatian kuna ]': 'Croatian kuna',
                   '[Hungarian forint ]': 'Hungarian forint',
                   '[Indonesian rupiah ]': 'Indonesian rupiah',
                   '[Israeli shekel ]': 'Israeli shekel',
                   '[Indian rupee ]': 'Indian rupee',
                   '[Iceland krona ]': 'Iceland krona',
                   '[Japanese yen ]': 'Japanese yen',
                   '[Korean won ]': 'Korean won',
                   '[Lithuanian litas ]': 'Lithuanian litas',
                   '[Latvian lats ]': 'Latvian lats',
                   '[Maltese lira ]': 'Maltese lira',
                   '[Mexican peso ]': 'Mexican peso',
                   '[Malaysian ringgit ]':'Malaysian ringgit',
                   '[Norwegian krone ]':'Norwegian krone',
                   '[New Zealand dollar ]': 'New Zealand dollar',
                   '[Philippine peso ]': 'Philippine peso',
                   '[Polish zloty ]':'Polish zloty',
                   '[Romanian leu ]': 'Romanian leu',
                   '[Russian rouble ]': 'Russian rouble', 
                   '[Swedish krona ]': 'Swedish krona', 
                   '[Singapore dollar ]': 'Singapore dollar',
                   '[Slovenian tolar ]': 'Slovenian tolar',
                   '[Slovak koruna ]': 'Slovak koruna',
                   '[Thai baht ]': 'Thai baht', 
                   '[Turkish lira ]': 'Turkish lira', 
                   '[US dollar ]': 'US dollar',
                   '[South African rand ]': 'South African rand'}, inplace=True)

# %%
df
# Out:
#             Time Australian dollar Bulgarian lev Brazilian real  \
# 0     2023-12-15            1.6324        1.9558         5.4085
# 1     2023-12-14            1.6288        1.9558         5.3349
# 2     2023-12-13            1.6452        1.9558         5.3609
# 3     2023-12-12            1.6398        1.9558         5.3327
# 4     2023-12-11             1.642        1.9558         5.3169
# ...          ...               ...           ...            ...
# 6451  1999-01-08            1.8406           NaN            NaN
# 6452  1999-01-07            1.8474           NaN            NaN
# 6453  1999-01-06            1.8820           NaN            NaN
# 6454  1999-01-05            1.8944           NaN            NaN
# 6455  1999-01-04            1.9100           NaN            NaN
#
#      Canadian dollar Swiss franc Chinese yuan renminbi Cypriot pound  \
# 0             1.4653      0.9488                7.7812           NaN
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Australian dollar', 'Bulgarian lev', 'Brazilian real',
#        'Canadian dollar', 'Swiss franc', 'Chinese yuan renminbi',
#        'Cypriot pound', 'Czech koruna', 'Danish krone', 'Estonian kroon',
#        'UK pound sterling', 'Greek drachma', 'Hong Kong dollar',
#        'Croatian kuna', 'Hungarian forint', 'Indonesian rupiah',
#        'Israeli shekel', 'Indian rupee', 'Iceland krona', 'Japanese yen',
#        'Korean won', 'Lithuanian litas', 'Latvian lats', 'Maltese lira',
#        'Mexican peso', 'Malaysian ringgit', 'Norwegian krone',
#        'New Zealand dollar', 'Philippine peso', 'Polish zloty', 'Romanian leu',
#        'Russian rouble', 'Swedish krona', 'Singapore dollar',
#        'Slovenian tolar', 'Slovak koruna', 'Thai baht', 'Turkish lira',
#        'US dollar', 'South African rand'],
#       dtype='object')

# %%
# df.info()

# %%
# df.duplicated().tail(60)

# %%
# df.describe()

# %%
# df.isnull().sum()

# %%
# df.nunique()

# %%
df['Time'] = pd.to_datetime(df['Time'])
df.sort_values(by="Time", inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#         Time Australian dollar Bulgarian lev Brazilian real Canadian dollar  \
# 0 1999-01-04            1.9100           NaN            NaN          1.8004
# 1 1999-01-05            1.8944           NaN            NaN          1.7965
# 2 1999-01-06            1.8820           NaN            NaN          1.7711
# 3 1999-01-07            1.8474           NaN            NaN          1.7602
# 4 1999-01-08            1.8406           NaN            NaN          1.7643
#
#   Swiss franc Chinese yuan renminbi Cypriot pound Czech koruna Danish krone  \
# 0      1.6168                   NaN       0.58231       35.107       7.4501
# 1      1.6123                   NaN       0.58230       34.917       7.4495
# 2      1.6116                   NaN       0.58200       34.850       7.4452
# 3      1.6165                   NaN       0.58187       34.886       7.4431
# 4      1.6138                   NaN       0.58187       34.938       7.4433
#
# ...

# %%
euro_to_drachma = df[['Time','Greek drachma']].copy()
euro_to_drachma['Greek drachma'].value_counts()
# Out:
# Greek drachma
# 340.75    9
# -         6
# 326.30    5
# 336.60    5
# 326.40    5
#          ..
# 332.95    1
# 333.10    1
# 333.18    1
# 333.25    1
# 331.28    1
# Name: count, Length: 323, dtype: int64

# %%
euro_to_drachma = euro_to_drachma[euro_to_drachma['Greek drachma'] != '-']
euro_to_drachma['Greek drachma'] = euro_to_drachma['Greek drachma'].astype(float)
euro_to_drachma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6450 entries, 0 to 6455
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           6450 non-null   datetime64[ns]
#  1   Greek drachma  514 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 151.2 KB

# %% [markdown]
# ### Visualizations

# %%
sns.set_theme()
ax = sns.lineplot(x = euro_to_drachma['Time'],y = euro_to_drachma['Greek drachma'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, size=10)
# Out:
# C:\Users\κική\AppData\Local\Temp\ipykernel_1204\3805243727.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, size=10)
# [Text(10592.0, 0, '1999-01'),
#  Text(10682.0, 0, '1999-04'),
#  Text(10773.0, 0, '1999-07'),
#  Text(10865.0, 0, '1999-10'),
#  Text(10957.0, 0, '2000-01'),
#  Text(11048.0, 0, '2000-04'),
#  Text(11139.0, 0, '2000-07'),
#  Text(11231.0, 0, '2000-10'),
#  Text(11323.0, 0, '2001-01')]

# %%
ax = sns.lineplot(x = euro_to_drachma['Time'],y = euro_to_drachma['Greek drachma'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, size=10) 
ax.set(title='Original values')
fig, axes = plt.subplots(3, 2)
fig.set_figheight(15)
fig.set_figwidth(15)


sns.lineplot(x = euro_to_drachma['Time'],y = euro_to_drachma['Greek drachma'], ax=axes[0,0]).set(title='Original values')
sns.lineplot(x = euro_to_drachma['Time'],y = euro_to_drachma['Greek drachma'].rolling(7).mean(), ax=axes[0,1]).set(title='Rolling Window:7')
sns.lineplot(x = euro_to_drachma['Time'],y = euro_to_drachma['Greek drachma'].rolling(30).mean(), ax=axes[1,0]).set(title='Rolling Window:30')
sns.lineplot(x = euro_to_drachma['Time'],y = euro_to_drachma['Greek drachma'].rolling(50).mean(), ax=axes[1,1]).set(title='Rolling Window:50')
sns.lineplot(x = euro_to_drachma['Time'],y = euro_to_drachma['Greek drachma'].rolling(100).mean(), ax=axes[2,0]).set(title='Rolling Window:100')
sns.lineplot(x = euro_to_drachma['Time'],y = euro_to_drachma['Greek drachma'].rolling(365).mean(), ax=axes[2,1]).set(title='Rolling Window:365')
# Out:
# C:\Users\κική\AppData\Local\Temp\ipykernel_1204\1305260836.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, size=10)
# [Text(0.5, 1.0, 'Rolling Window:365')]

# %%
euro_to_drachma['rolling_mean'] = euro_to_drachma['Greek drachma'].rolling(30).mean()
euro_to_drachma
# Out:
#            Time  Greek drachma  rolling_mean
# 0    1999-01-04         327.15           NaN
# 1    1999-01-05         324.70           NaN
# 2    1999-01-06         324.72           NaN
# 3    1999-01-07         324.40           NaN
# 4    1999-01-08         324.00           NaN
# ...         ...            ...           ...
# 6451 2023-12-11            NaN           NaN
# 6452 2023-12-12            NaN           NaN
# 6453 2023-12-13            NaN           NaN
# 6454 2023-12-14            NaN           NaN
# 6455 2023-12-15            NaN           NaN
#
# [6450 rows x 3 columns]
